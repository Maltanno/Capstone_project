# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('data.csv', header=[0,1], index_col=0)
data.head()
# Out:
#                           A                                            \
#                     1. open 2. high 3. low 4. close 5. adjusted close
# date
# 1999-11-01 00:00:00     NaN     NaN    NaN      NaN               NaN
# 1999-11-02 00:00:00     NaN     NaN    NaN      NaN               NaN
# 1999-11-03 00:00:00     NaN     NaN    NaN      NaN               NaN
# 1999-11-04 00:00:00     NaN     NaN    NaN      NaN               NaN
# 1999-11-05 00:00:00     NaN     NaN    NaN      NaN               NaN
#
#                                                                            AA  \
#                     6. volume 7. dividend amount 8. split coefficient 1. open
# date
# 1999-11-01 00:00:00       NaN                NaN                  NaN     NaN
# 1999-11-02 00:00:00       NaN                NaN                  NaN     NaN
# 1999-11-03 00:00:00       NaN                NaN                  NaN     NaN
# ...

# %%
syms = list(set([x[0] for x in data.columns]))
syms.sort()
syms[-1]
# Out:
# 'ZYME'

# %%
change_dict={}
for sym in syms:
    dates = {}
    for row in data[sym].iterrows():
        dates[row[0]] = row[1]['4. close'] - row[1]['1. open']
    change_dict[sym] = dates

# %%
change_df = pd.DataFrame(change_dict)
change_df.head()
# Out:
#                       A  AA  AAIC  AAN  AAP  AAT  AB  ABB  ABBV  ABC  ...  \
# 1999-11-01 00:00:00 NaN NaN   NaN  NaN  NaN  NaN NaN  NaN   NaN  NaN  ...
# 1999-11-02 00:00:00 NaN NaN   NaN  NaN  NaN  NaN NaN  NaN   NaN  NaN  ...
# 1999-11-03 00:00:00 NaN NaN   NaN  NaN  NaN  NaN NaN  NaN   NaN  NaN  ...
# 1999-11-04 00:00:00 NaN NaN   NaN  NaN  NaN  NaN NaN  NaN   NaN  NaN  ...
# 1999-11-05 00:00:00 NaN NaN   NaN  NaN  NaN  NaN NaN  NaN   NaN  NaN  ...
#
#                      ZBH  ZEN  ZEPP  ZIM  ZNH  ZTO  ZTR  ZTS  ZUO  ZYME
# 1999-11-01 00:00:00  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1999-11-02 00:00:00  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1999-11-03 00:00:00  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1999-11-04 00:00:00  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1999-11-05 00:00:00  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 2568 columns]

# %%
change_df.isna().sum()
# Out:
# A        5400
# AA       9665
# AAIC     5387
# AAN     10689
# AAP      5908
#         ...
# ZTO     10765
# ZTR     10765
# ZTS     10765
# ZUO     10765
# ZYME    10765
# Length: 2568, dtype: int64

# %%
change_df.tail(20)
# Out:
#                A     AA  AAIC   AAN   AAP   AAT    AB   ABB  ABBV   ABC  ...  \
# 2021-02-24  2.76  2.100  0.25  1.08 -0.79  0.94  0.57  0.35  2.69 -0.93  ...
# 2021-02-25 -2.71 -1.920 -0.14  0.11 -5.86 -0.01 -0.10 -0.45 -1.15 -3.01  ...
# 2021-02-26 -0.86  0.350  0.06 -0.31 -2.01 -1.71 -0.11 -0.32  0.06 -1.74  ...
# 2021-03-01  1.43  0.320 -0.01 -0.24  0.53  0.17  0.06  0.03 -0.12  1.25  ...
# 2021-03-02 -0.93  1.300  0.06 -0.51  1.71  0.58  0.13 -0.05 -1.00  1.03  ...
# 2021-03-03 -3.48  1.930 -0.07  0.12  1.64  1.38  0.07 -0.20 -0.15 -0.79  ...
# 2021-03-04 -3.70 -1.125  0.03  0.94 -0.35 -0.13 -1.56 -0.54 -0.85  0.29  ...
# 2021-03-05  0.26 -0.240  0.05  0.52  4.47  0.32  0.40  0.27  0.69  1.10  ...
# 2021-03-08 -0.23 -1.180  0.21  0.76  3.98  1.57 -0.08  0.07 -0.74  1.92  ...
# 2021-03-09  1.97  0.950 -0.12 -0.24 -4.96 -0.80 -0.18  0.25  0.31  2.34  ...
# 2021-03-10 -0.60  1.640  0.01 -0.17  2.35 -0.46  0.93  0.17  0.61  1.83  ...
# ...

# %%
change_df.to_csv('change.csv')

# %%
percent_change_dict={}
for sym in syms:
    dates = {}
    for row in data[sym].iterrows():
        dates[row[0]] = 100 * (row[1]['4. close'] - row[1]['1. open'])/row[1]['1. open']
    percent_change_dict[sym] = dates

# %%
percent_change_df = pd.DataFrame(percent_change_dict)
percent_change_df.head()
# Out:
#                       A  AA  AAIC  AAN  AAP  AAT  AB  ABB  ABBV  ABC  ...  \
# 1999-11-01 00:00:00 NaN NaN   NaN  NaN  NaN  NaN NaN  NaN   NaN  NaN  ...
# 1999-11-02 00:00:00 NaN NaN   NaN  NaN  NaN  NaN NaN  NaN   NaN  NaN  ...
# 1999-11-03 00:00:00 NaN NaN   NaN  NaN  NaN  NaN NaN  NaN   NaN  NaN  ...
# 1999-11-04 00:00:00 NaN NaN   NaN  NaN  NaN  NaN NaN  NaN   NaN  NaN  ...
# 1999-11-05 00:00:00 NaN NaN   NaN  NaN  NaN  NaN NaN  NaN   NaN  NaN  ...
#
#                      ZBH  ZEN  ZEPP  ZIM  ZNH  ZTO  ZTR  ZTS  ZUO  ZYME
# 1999-11-01 00:00:00  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1999-11-02 00:00:00  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1999-11-03 00:00:00  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1999-11-04 00:00:00  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1999-11-05 00:00:00  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 2568 columns]

# %%
percent_change_df.to_csv('percent_change.csv')

# %%
range_dict={}
for sym in syms:
    dates = {}
    for row in data[sym].iterrows():
        dates[row[0]] = row[1]['2. high'] - row[1]['3. low']
    range_dict[sym] = dates
range_df = pd.DataFrame(range_dict)
range_df.to_csv('range.csv')
range_df.head()
# Out:
#              A  AA  AAIC  AAN  AAP  AAT    AB  ABB  ABBV   ABC  ...     K  \
# 1999-11-01 NaN NaN  0.32  NaN  NaN  NaN  1.75  NaN   NaN  1.69  ...  2.06
# 1999-11-02 NaN NaN  0.38  NaN  NaN  NaN  5.37  NaN   NaN  0.69  ...  1.00
# 1999-11-03 NaN NaN  0.19  NaN  NaN  NaN  1.75  NaN   NaN  2.25  ...  0.87
# 1999-11-04 NaN NaN  0.19  NaN  NaN  NaN  1.44  NaN   NaN  0.44  ...  1.57
# 1999-11-05 NaN NaN  0.37  NaN  NaN  NaN  0.56  NaN   NaN  0.69  ...  1.25
#
#              KAI  KAMN  KAR  KB   KBH  KBR  KEN   KEP   KEX
# 1999-11-01  0.31  1.19  NaN NaN  1.00  NaN  NaN  0.57  0.38
# 1999-11-02  0.18  0.44  NaN NaN  1.25  NaN  NaN  0.75  0.37
# 1999-11-03  0.19  0.69  NaN NaN  0.44  NaN  NaN  0.69  0.06
# 1999-11-04  0.12  0.44  NaN NaN  0.44  NaN  NaN  0.69  0.68
# 1999-11-05  0.31  0.66  NaN NaN  1.63  NaN  NaN  0.44  0.38
#
# [5 rows x 1310 columns]

# %%
2+2
# Out:
# 4
